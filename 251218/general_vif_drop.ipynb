# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../data_모델용/1cha_GENERAL(shap_vif)_58.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   feature          58 non-null     object
#  1   shap_importance  58 non-null     float64
#  2   vif              58 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.5+ KB

# %%
df_filterd = df_filterd[df_filterd['vif']<9999]

# %%
df_filterd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   feature          43 non-null     object
#  1   shap_importance  43 non-null     float64
#  2   vif              43 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
df.to_csv('1cha_GENERAL(shap_vif)_vifFilterd_43.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd
import numpy as np

# 1. 원본 VIF 결과 로드
df_vif = pd.read_csv('../../data_모델용/1cha_GENERAL(shap_vif)_58.csv')

# 2. 빠진 컬럼(VIF가 inf이거나 9999 이상인 행)만 필터링
# 여기서 'inf'는 숫자형 무한대와 문자열 'inf'를 모두 체크해.
dropped_vif_list = df_vif[(df_vif['vif'] == np.inf) | 
                          (df_vif['vif'] == float('inf')) | 
                          (df_vif['vif'] >= 9999)]

# 3. 추가로 우리가 수동으로 제거했던 438개 컬럼(columns_drop)도 포함하고 싶다면 합칠 수 있어.
# (이전에 정리했던 columns_drop 리스트 활용)

# 4. 결과 출력 및 저장
print(f"VIF 문제로 제외된 컬럼 수: {len(dropped_vif_list)}개")
# dropped_vif_list.to_csv('VIP_dropped_columns_list.csv', index=False, encoding='utf-8-sig')

# print("🎉 빠진 컬럼 리스트 저장 완료! 파일명: VIP_dropped_columns_list.csv")
# Out:
# VIF 문제로 제외된 컬럼 수: 15개

# %%
dropped_vif_list['feature']
# Out:
# 7         할부금액_3M_R12M
# 12        이용가능카드수_신용체크
# 15       이용금액_R3M_신용체크
# 16          납부_통신비이용금액
# 17    할부금액_무이자_3M_R12M
# 28      증감율_이용건수_신용_전월
# 29          연체입금원금_B2M
# 33          연체입금원금_B0M
# 34        할부건수_3M_R12M
# 35         이용금액_R3M_신용
# 46    할부건수_유이자_3M_R12M
# 47        이용금액_신판_R12M
# 50          유효카드수_신용체크
# 53          정상청구원금_B5M
# 54        이용건수_신판_R12M
# Name: feature, dtype: object
