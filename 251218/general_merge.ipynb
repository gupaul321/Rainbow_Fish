# %%
import pandas as pd

# %%
general_target = pd.read_csv("../../data_모델용/혜민_300k_general_240636.csv")

# %%
general_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240636 entries, 0 to 240635
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   발급회원번호         240636 non-null  object
#  1   이용금액_신용_B0M    240636 non-null  int64
#  2   잔액_B0M         240636 non-null  int64
#  3   이용건수_신용_B0M    240636 non-null  int64
#  4   기준년월           240636 non-null  int64
#  5   Slope_Spend    240636 non-null  float64
#  6   Slope_Balance  240636 non-null  float64
#  7   Slope_Count    240636 non-null  float64
#  8   Churn_Score    240636 non-null  float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 16.5+ MB

# %%
general_data = pd.read_csv("../../data_모델용/1cha_GENERAL_300k_240636_57.csv")

# %%
general_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240636 entries, 0 to 240635
# Data columns (total 57 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   기준년월                240636 non-null  int64
#  1   발급회원번호              240636 non-null  object
#  2   수신거부여부_TM           240636 non-null  int64
#  3   탈회횟수_누적             240636 non-null  int64
#  4   최종탈회후경과월            240636 non-null  int64
#  5   유효카드수_신용체크          240636 non-null  int64
#  6   이용가능카드수_신용체크        240636 non-null  int64
#  7   이용금액_R3M_신용체크       240636 non-null  int64
#  8   이용금액_R3M_신용         240636 non-null  int64
#  9   _2순위카드이용금액          240636 non-null  int64
#  10  _2순위카드이용건수          240636 non-null  int64
#  11  CA이자율_할인전           240636 non-null  float64
#  12  카드이용한도금액_B1M        240636 non-null  int64
#  13  최종이용일자_체크           240636 non-null  int64
#  14  최종이용일자_할부           240636 non-null  int64
# ...

# %%
data_a = pd.merge(general_data,general_target, on=['발급회원번호','기준년월'], how='inner')

# %%
data_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240636 entries, 0 to 240635
# Data columns (total 64 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   기준년월                240636 non-null  int64
#  1   발급회원번호              240636 non-null  object
#  2   수신거부여부_TM           240636 non-null  int64
#  3   탈회횟수_누적             240636 non-null  int64
#  4   최종탈회후경과월            240636 non-null  int64
#  5   유효카드수_신용체크          240636 non-null  int64
#  6   이용가능카드수_신용체크        240636 non-null  int64
#  7   이용금액_R3M_신용체크       240636 non-null  int64
#  8   이용금액_R3M_신용         240636 non-null  int64
#  9   _2순위카드이용금액          240636 non-null  int64
#  10  _2순위카드이용건수          240636 non-null  int64
#  11  CA이자율_할인전           240636 non-null  float64
#  12  카드이용한도금액_B1M        240636 non-null  int64
#  13  최종이용일자_체크           240636 non-null  int64
#  14  최종이용일자_할부           240636 non-null  int64
# ...

# %%
# data_a.to_csv('1cha_선현_general_merge_data_240636_64.csv')
